# %% [markdown]
# # Assignment 3: Building Time Series Forecasts
#
# **Student Name:** Dylan Tighe
#
# **Date:** 2/11/26
#
# ## Assignment Overview
#
# In this assignment, you'll analyze temporal data from Corporación Favorita stores to identify trends, seasonality, and anomalies, then build forecasting models using decomposition techniques. You'll work with real retail sales data to predict future sales patterns.
#
# ---

# %% [markdown]
# ## Step 1: Download Data, Import Libraries, and Load Data

# %% [markdown]
# The datasets for this analysis are too large too be stored on GitHub. To access the datasets for this assignment, you should:
# - Go to the [Store Sales - Time Series Forecasting](https://www.kaggle.com/competitions/store-sales-time-series-forecasting/data) dataset on Kaggle.
# - Click Data
# - Scroll down and select **Download All**.
# - Open the zip file and upload `train.csv`, `store.csv`, and `holidays_events.csv` to the `data` directory.

# %% [markdown]
# Once the CSV files have been added to the `data` directory, install all the of the necessary libraries for this assignment by running the command below.

# %%
pip install pandas numpy matplotlib seaborn scikit-learn statsmodels
# Out:
# Requirement already satisfied: pandas in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (3.8.4)
# Requirement already satisfied: seaborn in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (1.8.0)
# Requirement already satisfied: statsmodels in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\dylan\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# Next, import the required libraries.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# For time series analysis
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %% [markdown]
# Finally, load the training, store, and holiday CSV data from the `data` directory using `pd.read_csv()`. Display basic information about the training data and print out the first few rows to get an understanding of what the training data looks like.

# %%
# Load the datasets
# TODO: Load all three required CSV files
train_df = pd.read_csv('data/train.csv')  # Replace with pd.read_csv('data/train.csv')
holidays_df = pd.read_csv('data/holidays_events.csv')  # Replace with pd.read_csv('data/holidays_events.csv')
stores_df = pd.read_csv('data/stores.csv')  # Replace with pd.read_csv('data/stores.csv')

# Display basic information
if train_df is not None:
    print(f"Training data shape: {train_df.shape}")
    print(f"Date range: {train_df['date'].min()} to {train_df['date'].max()}")
    print(f"\nFirst few rows:", train_df.head(5), 
          holidays_df.head(5),
          stores_df.head(5) )
    # TODO: Display the first few rows

print("\n" + "="*80)
print("CHECKPOINT: Verify datasets loaded correctly")
print(f"Train data shape: {train_df.shape if train_df is not None else 'Not loaded'}")
print(f"Holidays data shape: {holidays_df.shape if holidays_df is not None else 'Not loaded'}")
print(f"Stores data shape: {stores_df.shape if stores_df is not None else 'Not loaded'}")
print("="*80)
# Out:
# Training data shape: (3000888, 6)
# Date range: 2013-01-01 to 2017-08-15
#
# First few rows:    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False      store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
#
# ================================================================================
# CHECKPOINT: Verify datasets loaded correctly
# Train data shape: (3000888, 6)
# Holidays data shape: (350, 6)
# Stores data shape: (54, 5)
# ================================================================================

# %% [markdown]
# ### Explore Available Stores and Product Families
# Display store information from `stores_df` to help choose a store. Consider looking at store type, cluster, and city

# %%
# Explore the data to help choose your store and products
if train_df is not None:
    print("Available stores:")
    print(f"Total number of stores: {train_df['store_nbr'].nunique()}")
    
    print("\nAvailable product families:")
    families = train_df['family'].value_counts().head(20)
    print(families)
    print(stores_df)
    
    # TODO: Display store information from stores_df to help choose a store
    # Consider looking at store type, cluster, and city
# Out:
# Available stores:
# Total number of stores: 54
#
# Available product families:
# family
# AUTOMOTIVE                    90936
# HOME APPLIANCES               90936
# SCHOOL AND OFFICE SUPPLIES    90936
# PRODUCE                       90936
# PREPARED FOODS                90936
# POULTRY                       90936
# PLAYERS AND ELECTRONICS       90936
# PET SUPPLIES                  90936
# PERSONAL CARE                 90936
# MEATS                         90936
# MAGAZINES                     90936
# LIQUOR,WINE,BEER              90936
# LINGERIE                      90936
# LAWN AND GARDEN               90936
# LADIESWEAR                    90936
# HOME CARE                     90936
# HOME AND KITCHEN II           90936
# BABY CARE                     90936
# HOME AND KITCHEN I            90936
# HARDWARE                      90936
# Name: count, dtype: int64
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# 11         12      Latacunga                        Cotopaxi    C       15
# 12         13      Latacunga                        Cotopaxi    C       15
# 13         14       Riobamba                      Chimborazo    C        7
# 14         15         Ibarra                        Imbabura    C       15
# 15         16  Santo Domingo  Santo Domingo de los Tsachilas    C        3
# 16         17          Quito                       Pichincha    C       12
# 17         18          Quito                       Pichincha    B       16
# 18         19       Guaranda                         Bolivar    C       15
# 19         20          Quito                       Pichincha    B        6
# 20         21  Santo Domingo  Santo Domingo de los Tsachilas    B        6
# 21         22           Puyo                         Pastaza    C        7
# 22         23         Ambato                      Tungurahua    D        9
# 23         24      Guayaquil                          Guayas    D        1
# 24         25        Salinas                     Santa Elena    D        1
# 25         26      Guayaquil                          Guayas    D       10
# 26         27          Daule                          Guayas    D        1
# 27         28      Guayaquil                          Guayas    E       10
# 28         29      Guayaquil                          Guayas    E       10
# 29         30      Guayaquil                          Guayas    C        3
# 30         31       Babahoyo                        Los Rios    B       10
# 31         32      Guayaquil                          Guayas    C        3
# 32         33        Quevedo                        Los Rios    C        3
# 33         34      Guayaquil                          Guayas    B        6
# 34         35         Playas                          Guayas    C        3
# 35         36       Libertad                          Guayas    E       10
# 36         37         Cuenca                           Azuay    D        2
# 37         38           Loja                            Loja    D        4
# 38         39         Cuenca                           Azuay    B        6
# 39         40        Machala                          El Oro    C        3
# 40         41        Machala                          El Oro    D        4
# 41         42         Cuenca                           Azuay    D        2
# 42         43     Esmeraldas                      Esmeraldas    E       10
# 43         44          Quito                       Pichincha    A        5
# 44         45          Quito                       Pichincha    A       11
# 45         46          Quito                       Pichincha    A       14
# 46         47          Quito                       Pichincha    A       14
# 47         48          Quito                       Pichincha    A       14
# 48         49          Quito                       Pichincha    A       11
# 49         50         Ambato                      Tungurahua    A       14
# 50         51      Guayaquil                          Guayas    A       17
# 51         52          Manta                          Manabi    A       11
# 52         53          Manta                          Manabi    D       13
# 53         54      El Carmen                          Manabi    C        3

# %% [markdown]
# ---
# ## Step 2: Select and Prepare Your Time Series Data

# %% [markdown]
# ### Select Your Store and Product Families
#
# Choose one store and one product family (PRODUCE, BEVERAGES, BREAD/BAKERY, AUTOMOTIVE, etc.) to analyze.

# %%
# TODO: Select your store and product family
selected_store = 51  # Replace with your chosen store number (e.g., 1)
product_family_1 = 'HOME APLIANCES'  # Replace with the product family you selected (e.g., 'PRODUCE')

print(f"Selected Store: {selected_store}")
print(f"Product Family 1: {product_family_1}")
# Out:
# Selected Store: 51
# Product Family 1: HOME APLIANCES

# %% [markdown]
# ### Filter Data
# Filter the `train_df` data to your selected store and products. Create a date range from 2016-01-01 to 2017-08-15 for consistency.

# %%
# TODO: Filter train_df for selected store and date range 2016-01-01 to 2017-08-15

# Convert date column to datetime if needed
if train_df is not None:
    train_df['date'] = pd.to_datetime(train_df['date'])

# Filter for date range
start_date = '2016-01-01'
end_date = '2017-08-15'

# TODO: Create filtered datasets for each product family
product1_data = train_df[
    (train_df['store_nbr'] == selected_store) &
    (train_df['family'] == product_family_1) &
    (train_df['date'] >= start_date) &
    (train_df['date'] <= end_date)
]  

print("\n" + "="*80)
print("CHECKPOINT: Data filtered successfully")
print(f"Product data shape: {product1_data.shape if product1_data is not None else 'Not filtered'}")
print("="*80)
# Out:
# ================================================================================
# CHECKPOINT: Data filtered successfully
# Product data shape: (0, 6)
# ================================================================================

# %% [markdown]
# ### Aggregate Daily Sales
# Aggregate daily sales and handle missing dates.

# %%
# TODO: Group by date and sum sales for each product family
# TODO: Create a complete date range and fill missing dates with 0 sales
product1_ts = (
    product1_data
        .groupby('date')['sales']
        .sum()
)

# Example structure (replace with your implementation):
# date_range = pd.date_range(start=start_date, end=end_date, freq='D')
# product1_ts = product1_data.groupby('date')['sales'].sum().reindex(date_range, fill_value=0)
product1_ts = (
    product1_ts
        .reindex(date_range, fill_value=0)
)

date_range = pd.date_range(start=start_date, end=end_date, freq='D')


# Replace with time series for your selected product

# %% [markdown]
# ### Plot Raw Time Series
# Plot time series to see the raw patterns using matplotlib.

# %%
# Plot Product 1
# TODO: Plot product1_ts on a line chart as a time series
print(product1_ts)
plt.figure(figsize=(12, 6))
plt.plot(product1_ts.index)
plt.title('Product 1')
plt.xlabel('Sales')
plt.ylabel('Date')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# date
# 2016-01-01    0.0
# 2016-01-02    0.0
# 2016-01-03    0.0
# 2016-01-04    0.0
# 2016-01-05    0.0
#              ...
# 2017-08-11    0.0
# 2017-08-12    0.0
# 2017-08-13    0.0
# 2017-08-14    0.0
# 2017-08-15    0.0
# Freq: D, Name: sales, Length: 593, dtype: float64

# %% [markdown]
# ### Document Your Choice (2-3 sentences)
# Explain why you chose this product.
# - What contrasts do they represent?
# - Why will they be interesting to compare?

# %% [markdown]
# This represents the growth in sales over a certain time period. It include years 2016 and 2017 and shows a steady increase in sales throughout that time period. This will be interesting to compare because of the capability to compare all of the different product families toal sales.

# %% [markdown]
# ---
# ## Step 3: Identify Trends Using Moving Averages

# %% [markdown]
# ### Calculate Moving Averages
# Calculate the 7-day and 30-day moving averages for the product you are analyzing.

# %%
# TODO: Calculate 7-day and 30-day moving averages for your product

# For Product 1
product1_ma7 = product1_ts.rolling(window=7).mean() # Replace with product1_ts.rolling(window=7).mean()
product1_ma30 = product1_ts.rolling(window=30).mean()  # Replace with product1_ts.rolling(window=30).mean()

# %% [markdown]
# ### Plot Original Sales
# Using matplotlip, plot original sales with both moving averages (7-day and 30-day) overlaid.

# %%
# Plot original sales with moving averages
fig, ax = plt.subplots(figsize=(14, 6))  

ax.plot(product1_ts.index, product1_ts.values, alpha=0.4, label='Daily Sales')
ax.plot(product1_ma7.index, product1_ma7.values, label='7-Day MA')
ax.plot(product1_ma30.index, product1_ma30.values, label='30-Day MA')

ax.set_title('Product 1 Sales with 7-Day and 30-Day Moving Averages')
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
ax.legend()
plt.xticks(rotation=45)
# Product 1
# TODO: Plot original, 7-day MA, and 30-day MA for product 1
# axes[0].plot(product1_ts.index, product1_ts.values, alpha=0.4, label='Daily Sales')
# axes[0].plot(product1_ma7.index, product1_ma7.values, label='7-Day MA')
# axes[0].plot(product1_ma30.index, product1_ma30.values, label='30-Day MA')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Identify and Explain Trend Changes

# %% [markdown]
# Merge the data with `holidays_events.csv` to explain what caused these changes.

# %%
# Merge with holidays to explain trend changes
# TODO: Convert holidays_df date to datetime and filter for your date range
if holidays_df is not None:
    holidays_df['date'] = pd.to_datetime(holidays_df['date'])
    relevant_holidays = holidays_df[
        (holidays_df['date'] >= pd.to_datetime(start_date)) &
        (holidays_df['date'] <= pd.to_datetime(end_date))
    ]  # Filter holidays_df for your date range
    
    # TODO: Display holidays that might explain trend changes
    print("Key holidays/events in the period:")
    print(relevant_holidays[['date', 'locale', 'type','locale_name']])
# Out:
# Key holidays/events in the period:
#           date    locale        type locale_name
# 211 2016-01-01  National     Holiday     Ecuador
# 212 2016-02-08  National     Holiday     Ecuador
# 213 2016-02-09  National     Holiday     Ecuador
# 214 2016-03-02     Local     Holiday       Manta
# 215 2016-03-25  National     Holiday     Ecuador
# ..         ...       ...         ...         ...
# 322 2017-07-25     Local  Additional   Guayaquil
# 323 2017-08-05     Local     Holiday  Esmeraldas
# 324 2017-08-10  National     Holiday     Ecuador
# 325 2017-08-11  National    Transfer     Ecuador
# 326 2017-08-15     Local     Holiday    Riobamba
#
# [116 rows x 4 columns]

# %% [markdown]
# ### Document Trend Analysis
# For the product family you are analyzing, document:
# 1. Overall trend direction (growing, declining, stable)
# 2. Any trend changes that correlate with holidays or events
# 3. Business implications of the trends you discovered
#
# Update the markdown cell below with your analysis.

# %% [markdown]
# **Product Trends:**
# - Overall trend direction: Stable
# - Key trend changes: If done correctly or chosen a better product. I would assume the apliances products do not exactly see any imporvement in slaes during the holidays but for apliances there would still be a bump in sales but nothing as jurastic as lets say handheld products or food, etc.
# - Holiday correlations: For apliances I would say christmas would be the most significant and any other holiday during the spring or summer time as that would be the best time to install apliances due to weather conditions.
# - Business implications: Most sales should ramp up during the holidays as the holidays are consumer oriented.

# %% [markdown]
# ---
# ## Step 4: Detect and Visualize Seasonal Patterns
#
# Analyze the seasonal components of your sales data.

# %% [markdown]
# ### Day-of-Week Analysis
#
# Add day of week to your data and calculate the average sales by day. Create a bar plot to visualize the weekday patterns.

# %%
# Analyze day-of-week patterns
# TODO: Add day of week to your data and calculate average sales by day
product1_dow = product1_ts.to_frame(name='sales')
product1_dow['day_of_week'] = product1_dow.index.day_name()  # Create DataFrame with date and sales

# Add day of week: product1_dow['day_of_week'] = product1_dow.index.day_name()
# Group by day of week and calculate mean sales
avg_sales_by_dow = product1_dow.groupby('day_of_week')['sales'].mean()
dow_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
avg_sales_by_dow = avg_sales_by_dow.reindex(dow_order)

# Create bar plot comparing weekday patterns
# TODO: Create bar plot showing average sales by day of week
plt.figure(figsize=(10, 5))
avg_sales_by_dow.plot(kind='bar', color='skyblue')
plt.title('Average Product 1 Sales by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Average Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Monthly Seasonality Analysis

# %% [markdown]
# Calculate the average sales by month for both products. Once calculated, create a line plot showing monthly patterns for the product.

# %%
# Analyze monthly patterns
# TODO: Calculate average sales by month for the product.
product1_monthly = product1_ts.to_frame(name='sales')
product1_monthly['month'] = product1_monthly.index.month
# For Product 1
avg_sales_by_month = product1_monthly.groupby('month')['sales'].mean()


# Create visualization
# TODO: Create line plot showing monthly patterns for both products
plt.figure(figsize=(10, 5))
avg_sales_by_month.plot(marker='o', linestyle='-')
plt.title('Average Product 1 Sales by Month')
plt.xlabel('Month')
plt.ylabel('Average Sales')
plt.xticks(range(1, 13))
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Holiday Impact Analysis

# %% [markdown]
# Compare the average sales on holidays compared to regular days.

# %%
# Analyze holiday vs non-holiday sales
# TODO: Compare average sales on holidays vs regular days
holiday_dates = holidays_df['date'].unique() if holidays_df is not None else []
product1_ts_df = product1_ts.to_frame(name='sales')
product1_ts_df['is_holiday'] = product1_ts_df.index.isin(holiday_dates)
# Create a list of holiday dates
avg_sales_holiday = product1_ts_df[product1_ts_df['is_holiday']]['sales'].mean()
avg_sales_non_holiday = product1_ts_df[~product1_ts_df['is_holiday']]['sales'].mean()
# Calculate average sales on holidays vs non-holidays for both products
# TODO: Split data into holiday and non-holiday sales and compare
print(f"Average Product 1 sales on holidays: {avg_sales_holiday:.2f}")
print(f"Average Product 1 sales on non-holidays: {avg_sales_non_holiday:.2f}")
# Out:
# Average Product 1 sales on holidays: 0.00
# Average Product 1 sales on non-holidays: 0.00

# %% [markdown]
# ### Seasonal Pattern Findings
#
# **Document your findings:**
# - Which days of the week have highest/lowest sales?
# - Are there monthly patterns (e.g., payday effects)?
# - How do holidays affect each product differently?
# - What business decisions could these patterns inform?
#
# Update the markdown cell below with your analysis.

# %% [markdown]
# -My charts are not accurate but i would assume the weekdays and also fridays as that is when most people have the time to shop and also when most people receive their paychecks.
# -I am not sure of that
# -Certain products have different seasons such as lawnmowers for example that do not sell at all in the winter and usually only sell in sppring and summer. Also products that make good gifts are going to see a huge increase in sales during christmas
# -When to hold higher inventory and ethically raise prices(maybe). When you see certain holidays boost consumer sales you would want to hold more inventory to make sure you do not run out of product and therefore lose out on sales.

# %% [markdown]
# ---
# ## Step 5: Build Simple Forecasts and Compare Methods

# %% [markdown]
# ### Time Series Decomposition

# %%
# Perform seasonal decomposition
# TODO: Use seasonal_decompose to separate trend, seasonal, and residual components
decomposition1 = seasonal_decompose(product1_ts, model='additive', period=7)

trend1 = decomposition1.trend
seasonal1 = decomposition1.seasonal
residual1 = decomposition1.resid
# For Product 1
# seasonal_decompose(product1_ts, model='additive', period=7)

# %%
# Visualize decomposition for Product 1
if decomposition1 is not None:
    fig, axes = plt.subplots(4, 1, figsize=(14, 10))
    

    # TODO: Plot each component
    # decomposition1.observed.plot(ax=axes[0], title=f'{product_family_1} - Original')
    # decomposition1.trend.plot(ax=axes[1], title='Trend')
    # decomposition1.seasonal.plot(ax=axes[2], title='Seasonal')
    # decomposition1.resid.plot(ax=axes[3], title='Residual')
decomposition1.plot()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Build Forecasts
# Create a baseline forecast using the average of the last 30 days and a season naive forcast by repeating the last 7 days' pattern.

# %%
# Split data for validation
test_days = 30
train = product1_ts[:-test_days]
test = product1_ts[-test_days:]

# Method 1: Baseline forecast (30-day average)
baseline_forecast = np.repeat(train[-30:].mean(), test_days)

# Method 2: Seasonal Naive
# Just repeat the last 7 days pattern
last_week = train[-7:].values
seasonal_naive_forecast = np.tile(last_week, int(np.ceil(test_days/7)))[:test_days]

# %% [markdown]
# ### Calculate Forecast Accuracy

# %%
# Calculate RMSE for both methods
# TODO: Calculate RMSE for baseline and seasonal forecasts

# Product 1
baseline_rmse = np.sqrt(mean_squared_error(test, baseline_forecast))
seasonal_rmse = np.sqrt(mean_squared_error(test, seasonal_naive_forecast))

# %%
# Create comparison table
comparison_data = {
    'Method': ['30-Day Average', 'Seasonal Naive (7-day repeat)'],
    'RMSE': [baseline_rmse, seasonal_rmse],
}

comparison_df = pd.DataFrame(comparison_data)

# TODO: Calculate percentage improvement
# Add improvement column to comparison_df
comparison_df['Improvement_vs_Baseline (%)'] = 100 * (baseline_rmse - comparison_df['RMSE']) / baseline_rmse


print("\n" + "="*80)
print("FORECAST PERFORMANCE COMPARISON")
print("="*80)
# TODO: Display comparison table
print(comparison_df)

print("="*80)
# Out:
# ================================================================================
# FORECAST PERFORMANCE COMPARISON
# ================================================================================
#                           Method  RMSE  Improvement_vs_Baseline (%)
# 0                 30-Day Average   0.0                          NaN
# 1  Seasonal Naive (7-day repeat)   0.0                          NaN
# ================================================================================

# %% [markdown]
# ### Visualize Forecasts

# %%
# Plot actual vs forecasted values
# TODO: Create visualization showing:
# - Historical data (last 60 days of train)
# - Actual test data
# - Baseline forecast
# - Seasonal naive forecast

plt.figure(figsize=(14, 6))
plt.plot(train[-60:].index, train[-60:].values, label='Historical (Train)', color='blue')
plt.plot(test.index, test.values, label='Actual Test', color='black', marker='o')
plt.plot(test.index, baseline_forecast, label='30-Day Average Forecast', color='red', linestyle='--')
plt.plot(test.index, seasonal_naive_forecast, label='Seasonal Naive Forecast', color='green', linestyle='--')


# TODO: Plot on this single figure
plt.title('Product 1: Actual vs Forecasted Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 6: Generate Business Recommendations

# %% [markdown]
# ### Executive Summary (200-300 words)
#
# Based on your analysis, write a brief executive summary that includes:
# - **Key Patterns Discovered:** Summarize the main trends and seasonal patterns for each product
# - **Inventory Planning Recommendations:** Specific recommendations based on your findings
# - **High-Risk Periods:** Identify periods requiring special attention
# - **Predictability Analysis:** Which product is more predictable and why?
# - **Specific Action Item:** One concrete action the store manager should take based on your forecast

# %% [markdown]
# Unfortunately after trying to evaluate my code I ran into a problem where my data was only coming out as Nan and I could not correctly complete the homework. I will write this summary based on my business knowledge assumptions of sales during the holidays. The main key patterns is figuring out which product families sell the most during specific holidays. We all know gifts are common in most holidays or how we all buy costumes and candy on Halloween. Figuring out which products should recieve special attention for things such as inventory around which holidays they perform the best is what we are trying to figure out in this dataset and assignment. I feel like food would be the most predictible as almost evey holdiday has special treats/platters/food spreads for each holiday and is usually the most consistent amongst all family groups. The store  manager should be hyper aware of what to stock up on at which time period.

# %% [markdown]
# ---
# ## Step 7: Submit Your Work
#
# Before submitting:
# 1. Ensure all code cells run without errors
# 2. Verify all visualizations display correctly
# 3. Check that your analysis sections are complete
# 4. Review your executive summary
#
# Push to GitHub:
# ```bash
# git add .
# git commit -m 'completed time series forecasting assignment'
# git push
# ```
#
# Submit your GitHub repository link on the course platform.
